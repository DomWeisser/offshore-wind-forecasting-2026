# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LongitudeFormatter, LatitudeFormatter
from matplotlib.patheffects import withStroke

# %%
sites = [
    {'name': 'Beatrice', 'lat': 58.254, 'lon': -2.885},
    {'name': 'Hornsea', 'lat': 53.885, 'lon': 1.791},
    {'name': 'Walney', 'lat': 54.088, 'lon': -3.738},
    {'name': 'Gode Wind', 'lat': 54.04, 'lon': 7.00, 'dx': -0.8, 'dy': 0.2},
    {'name': 'Baltic Eagle', 'lat': 54.83, 'lon': 13.80, 'dx': -2.0, 'dy': 0.2},  
    {'name': "Îles d'Yeu\net de Noirmoutier", 'lat': 46.87, 'lon': -2.51},
]

fig = plt.figure(figsize=(12, 10))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent([-5, 15, 45, 60], crs=ccrs.PlateCarree())

ax.add_feature(cfeature.LAND, facecolor='lightyellow')
ax.add_feature(cfeature.OCEAN, facecolor='lightblue')

ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle='--')

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=0.5,
                  color='gray', alpha=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LongitudeFormatter()
gl.yformatter = LatitudeFormatter()
gl.xlabel_style = {'size': 10}
gl.ylabel_style = {'size': 10}

for site in sites:

    ax.plot(site['lon'], site['lat'], marker='o', color='red', markersize=8,
            transform=ccrs.PlateCarree())


    dx = site.get('dx', 0.2)
    dy = site.get('dy', 0.2)


    ax.text(site['lon'] + dx, site['lat'] + dy, site['name'],
            fontsize=22, fontweight='bold', transform=ccrs.PlateCarree(),
            path_effects=[withStroke(linewidth=3, foreground='white')])


plt.savefig(r'C:\Users\dweis\OneDrive\Documents\Career\Research Paper\Figures\Selecting Source Farms\Source_Locations.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
colors = ['blue', 'green', 'purple', 'red', 'yellow', 'orange']

sites = [
    {'name': 'Beatrice', 'lat': 58.13, 'lon': -3.07, 'cluster': 1},
    {'name': 'London Array', 'lat': 51.64389, 'lon': 1.55361, 'cluster': 0},
    {'name': 'Walney', 'lat': 54.088, 'lon': -3.738, 'cluster': 4},
    {'name': 'Gode Wind', 'lat': 54.05, 'lon': 7.03, 'cluster': 5},
    {'name': 'Baltic Eagle', 'lat': 54.83, 'lon': 13.87, 'cluster': 2},
    {'name': "Îles d'Yeu et de Noirmoutier", 'lat': 46.87, 'lon': -2.51, 'cluster': 0},
    {'name': 'Dogger Bank (Phase A)', 'lat': 54.77, 'lon': 1.91, 'cluster': 3},
    {'name': 'Moray Firth', 'lat': 58.167, 'lon': -2.6985, 'cluster': 1},
    {'name': 'Seagreen', 'lat': 56.588, 'lon': -1.741, 'cluster': 3},
    {'name': 'Borssele (Phase 1,2)', 'lat': 51.703, 'lon': 3.076, 'cluster': 1},
    {'name': 'Borssele (Phase 3,4)', 'lat': 51.707, 'lon': 2.912, 'cluster': 1},
    {'name': 'Hollandse Kust Noord', 'lat': 52.715, 'lon': 4.251, 'cluster': 1},
    {'name': 'Hollandse Kust Zuid', 'lat': 52.367, 'lon': 4.117, 'cluster': 1},
    {'name': 'Greater Gabbard', 'lat': 51.88, 'lon': 1.94, 'cluster': 0},
    {'name': 'Race Bank', 'lat': 53.275, 'lon': 0.833, 'cluster': 4},
    {'name': 'Triton Knoll', 'lat': 53.4, 'lon': 0.9, 'cluster': 4},
    {'name': 'Baie de Saint-Brieuc', 'lat': 48.86, 'lon': -2.535, 'cluster': 0},
    {'name': 'Gwynt y Mor', 'lat': 53.45, 'lon': -3.583, 'cluster': 0},
    {'name': 'East Anglia One', 'lat': 52.666, 'lon': 2.296, 'cluster': 4},
    {'name': 'Hornsea (Project 1)', 'lat': 53.885, 'lon': 1.791, 'cluster': 3},
    {'name': 'Hornsea (Project 2)', 'lat': 53.91, 'lon': 1.552, 'cluster': 3},
    {'name': 'Seamade', 'lat': 51.675, 'lon': 2.8, 'cluster': 0},
    {'name': 'Kriegers Flak', 'lat': 55.063, 'lon': 13.005, 'cluster': 2},
    {'name': 'Borkum Riffgrund', 'lat': 53.9667, 'lon': 6.5623, 'cluster': 5},
    {'name': 'Gemini', 'lat': 54.036, 'lon': 5.963, 'cluster': 5},
    {'name': 'Horns Rev', 'lat': 55.697, 'lon': 7.669, 'cluster': 2},
    {'name': 'Dieppe - Le Treport', 'lat': 50.15, 'lon': 1.12, 'cluster': 0},
    {'name': 'Hohe See', 'lat': 54.433, 'lon': 6.317, 'cluster': 5},
    {'name': 'Fecamp', 'lat': 49.904, 'lon': 0.220, 'cluster': 0}
]


fig = plt.figure(figsize=(12,10))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.set_extent([-5, 15, 45, 60], crs=ccrs.PlateCarree())

ax.add_feature(cfeature.LAND, facecolor='lightyellow')
ax.add_feature(cfeature.OCEAN, facecolor='lightblue')

ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle='--')

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=0.5, color='gray', alpha=0.5, linestyle='--')
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LongitudeFormatter()
gl.yformatter = LatitudeFormatter()
gl.xlabel_style = {'size': 10}
gl.ylabel_style = {'size': 10}

for site in sites:
    ax.plot(site['lon'], site['lat'], marker='o', color=colors[site['cluster']], markersize=15, transform=ccrs.PlateCarree(), path_effects=[withStroke(linewidth=2.5, foreground='black')])

plt.savefig('C:\Users\dweis\OneDrive\Documents\Career\Research Paper\Figures\Selecting Source Farms\Wind Farm Clusters.png')
plt.show()
